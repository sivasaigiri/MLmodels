# %% [markdown]
# <a href="https://colab.research.google.com/github/sivasaigiri/MLmodels/blob/main/K_means.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **K-means clustering model**

# %% [markdown]
# ## **Import Libraries**

# %%
import numpy as np
import pandas as pd
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt

# %% [markdown]
# ## **Load Data**

# %%
from sklearn.datasets import make_blobs
X,y = make_blobs(n_samples = 300, centers=4, random_state=42)

# %% [markdown]
# ## **Visualize Data**

# %%
plt.scatter(X[:, 0], X[:, 1], s=50, cmap='viridis')
plt.show()
# Out:
# <ipython-input-5-05af6c9be430>:1: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   plt.scatter(X[:, 0], X[:, 1], s=50, cmap='viridis')

# %% [markdown]
# ## **Create Model**

# %%
kmeans = KMeans(n_clusters=4)
kmeans.fit(X)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# KMeans(n_clusters=4)

# %% [markdown]
# ##  **Inspect Results**

# %%
centers = kmeans.cluster_centers_
labels = kmeans.labels_

# %% [markdown]
# ## **Visualize**

# %%
plt.scatter(X[:,0], X[:, 1], c= labels, s=50, cmap='viridis')
plt.scatter(centers[:, 0], centers[:, 1], c='red', s=200, alpha=0.75, marker = 'X')

plt.show()
